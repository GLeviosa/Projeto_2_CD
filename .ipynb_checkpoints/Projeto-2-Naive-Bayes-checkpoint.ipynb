# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import os.path
import numpy as np

# %% [markdown]
# # Projeto 2 - Classificador Automático de Sentimento
#
# Você foi contratado por uma empresa parar analisar como os clientes estão reagindo a um determinado produto no Twitter. A empresa deseja que você crie um programa que irá analisar as mensagens disponíveis e classificará como "relevante" ou "irrelevante". Com isso ela deseja que mensagens negativas, que denigrem o nome do produto, ou que mereçam destaque, disparem um foco de atenção da área de marketing.<br /><br />
# Como aluno de Ciência dos Dados, você lembrou do Teorema de Bayes, mais especificamente do Classificador Naive-Bayes, que é largamente utilizado em filtros anti-spam de e-mails. O classificador permite calcular qual a probabilidade de uma mensagem ser relevante dadas as palavras em seu conteúdo.<br /><br />
# Para realizar o MVP (*minimum viable product*) do projeto, você precisa implementar uma versão do classificador que "aprende" o que é relevante com uma base de treinamento e compara a performance dos resultados com uma base de testes.<br /><br />
# Após validado, o seu protótipo poderá também capturar e classificar automaticamente as mensagens da plataforma.
#
# ## Informações do Projeto
#
# Prazo: 19/Set até às 23:59.<br />
# Grupo: 2 ou 3 pessoas - grupos com 3 pessoas terá uma rubrica diferenciada.<br /><br />
# Entregáveis via GitHub:
# * Arquivo notebook com o código do classificador, seguindo as orientações abaixo.
# * Arquivo Excel com as bases de treinamento e teste totalmente classificado.
#
# **NÃO gravar a key do professor no arquivo**
#
#
# ### Entrega Intermediária: Check 1 - APS 2
#
# Até o dia 10/Set às 23:59, xlsx deve estar no Github com as seguintes evidências:
#
#   * Produto escolhido.
#   * Arquivo Excel contendo a base de treinamento e a base de testes já classificadas.
#
# Sugestão de leitura:<br />
# https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/

# %% [markdown]
# ___
#
# ## Parte I - Adquirindo a Base de Dados
#
# Acessar o notebook **Projeto-2-Planilha** para realizar a coleta dos dados. O grupo deve classificar os dados coletados manualmente.

# %% [markdown]
# ___
# ## Parte II - Montando o Classificador Naive-Bayes
#
# Com a base de treinamento montada, comece a desenvolver o classificador. Não se esqueça de implementar o Laplace Smoothing (https://en.wikipedia.org/wiki/Laplace_smoothing).
#
# Opcionalmente:
# * Limpar as mensagens removendo os caracteres: enter, :, ", ', (, ), etc. Não remover emojis.<br />
# * Corrigir separação de espaços entre palavras e/ou emojis.
# * Propor outras limpezas/transformações que não afetem a qualidade da informação.
#
# Escreva o seu código abaixo:

# %%
tweets = pd.read_excel("tweets_Game Marvel's Spider-Man - PS4_201809101603.xlsx")
lista_lixo = [',','@','/',':',';','rt','r$','\n','\(','\)','#','\?','-','"','\[','\]']

for e in lista_lixo:
    tweets.Treinamento = tweets.Treinamento.replace(e,'',regex=True)
tweets
# Out:
#                                            Treinamento  Relevancia
# 0    game marvel's spiderman  ps4 caão submarino  r...           0
# 1     ignbrasil o melhor game do homemaranha em dez...           1
# 2    apesar de todas as polêmicas envolvendo reclam...           1
# 3     promobitoficial promoção ofea  prévenda jogo ...           0
# 4     ignbrasil o melhor game do homemaranha em dez...           1
# 5     ignbrasil o melhor game do homemaranha em dez...           1
# 6    declare sua independência com o maravilhoso sp...           0
# 7    o pablomiyazawa conversou com a diretora de ae...           0
# 8     ignbrasil o melhor game do homemaranha em dez...           1
# 9     ignbrasil o melhor game do homemaranha em dez...           1
# 10   americanas game marvel's spiderman  ps4 só r$ ...           0
# 11    ignbrasil o pablomiyazawa conversou com a dir...           0
# 12   o melhor game do homemaranha em dez anos traz ...           1
# 13   i liked a youtube video httpst.colkqtvgrxnx ao...           1
# 14    ignbrasil o pablomiyazawa conversou com a dir...           0
# 15    ignbrasil o melhor game do homemaranha em dez...           1
# 16    ignbrasil o melhor game do homemaranha em dez...           1
# 17    ignbrasil o melhor game do homemaranha em dez...           1
# 18    ignbrasil o melhor game do homemaranha em dez...           1
# 19    ignbrasil o melhor game do homemaranha em dez...           1
# 20    ignbrasil o melhor game do homemaranha em dez...           1
# 21   submarino game marvel's spiderman  ps4 caão su...           0
# 22   gostei de um vídeo youtube httpst.col7yizjuuuh...           1
# 23    ignbrasil o pablomiyazawa conversou com a dir...           0
# 24   por ignbrasil a principal missão do estúdio in...           0
# 25    ignbrasil o melhor game do homemaranha em dez...           1
# 26   americanas game marvel's spiderman  ps4 só r$ ...           0
# 27    ignbrasil o melhor game do homemaranha em dez...           1
# 28    ignbrasil o melhor game do homemaranha em dez...           1
# 29    ignbrasil o melhor game do homemaranha em dez...           1
# ..                                                 ...         ...
# 316   rafafernandes64 meu deus rapaz pediu à insomn...           1
# 317   rafafernandes64 meu deus rapaz pediu à insomn...           1
# 318   soulunabrasill feliz cumpleaños a lo pior spi...           0
# 319  gostei de um vídeo youtube httpst.consgtrolqlm...           1
# 320  bundlezinho sensacional de ps4 pro todo estili...           0
# 321  mais um episódio da nossa série sensacional do...           0
# 322   rafafernandes64 meu deus rapaz pediu à insomn...           1
# 323   rafafernandes64 meu deus rapaz pediu à insomn...           1
# 324   rafafernandes64 meu deus rapaz pediu à insomn...           1
# 325   rafafernandes64 meu deus rapaz pediu à insomn...           1
# 326  spider man ps4 pro  12 o final emocionante e s...           1
# 327  marvel's spiderman o amigo da vizinhança volto...           1
# 328  o alan vai começar uma série do novo jogo do s...           0
# 329   soulunabrasill feliz cumpleaños a lo pior spi...           0
# 330  essa minha internet é uma vergonha 9h  baixand...           0
# 331  fiz meu trabalho rapidinho e sai da escola ago...           1
# 332  um npc do marvel spider man me parou e falou v...           1
# 333        é pedir dms um ps4 com fifa 19 e spider man           1
# 334  octaviobuzz boa tarde octávioainda não recebi ...           0
# 335  spiderman e o easter egg mais triste da histór...           1
# 336   rafafernandes64 meu deus rapaz pediu à insomn...           1
# 337   rafafernandes64 meu deus rapaz pediu à insomn...           1
# 338  spiderman e o easter egg mais triste da histór...           1
# 339  gostei de um vídeo youtube httpst.cof350tcjdg9...           1
# 340   rafafernandes64 meu deus rapaz pediu à insomn...           1
# 341   napgaiola to tao triste alguem compra o spide...           1
# 342   fuck_off_matt spider man já se tornou o game ...           1
# 343   kokzviana no momento não preciso de muito pra...           1
# 344   rafafernandes64 meu deus rapaz pediu à insomn...           1
# 345             o alan suando enquanto joga spider man           1
#
# [346 rows x 2 columns]

# %%
strain_col = pd.Series(np.sum(tweets.Treinamento + " ").split())
relevs_col = tweets.Relevancia
strain_col.value_counts()
# Out:
# de                     273
# à                      237
# um                     165
# o                      163
# jogo                   157
# no                     152
# pra                    140
# spider                 140
# os                     133
# casamento              131
# pedido                 131
# meu                    126
# insomniac              124
# man                    124
# dele                   120
# namorada               119
# pediu                  119
# rafafernandes64        118
# rapaz                  118
# colocaram              118
# deus                   118
# colocar                118
# caras                  118
# como…                  118
# do                     102
# e                       89
# que                     81
# ps4                     60
# a                       59
# game                    48
#                       ...
# one                      1
# kingdom                  1
# temporada                1
# passada                  1
# jane                     1
# marketing                1
# vizinhança               1
# vamos                    1
# httpst.codrqdzuvfsw      1
# corações                 1
# antes.                   1
# chega                    1
# criativo                 1
# httpst.coe2a55zspsf      1
# promobitoficial          1
# desse                    1
# tela                     1
# esponjinha_man           1
# httpst.co8duw6hpv…       1
# 153°                     1
# fácil                    1
# chorei                   1
# internet                 1
# httpst.cozhwyg3aqa5      1
# blog!                    1
# referencia.              1
# economize                1
# octávioainda             1
# cai                      1
# fode                     1
# Length: 1075, dtype: int64

# %%
prob = relevs_col.value_counts()
relevs_col
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      1
# 5      1
# 6      0
# 7      0
# 8      1
# 9      1
# 10     0
# 11     0
# 12     1
# 13     1
# 14     0
# 15     1
# 16     1
# 17     1
# 18     1
# 19     1
# 20     1
# 21     0
# 22     1
# 23     0
# 24     0
# 25     1
# 26     0
# 27     1
# 28     1
# 29     1
#       ..
# 316    1
# 317    1
# 318    0
# 319    1
# 320    0
# 321    0
# 322    1
# 323    1
# 324    1
# 325    1
# 326    1
# 327    1
# 328    0
# 329    0
# 330    0
# 331    1
# 332    1
# 333    1
# 334    0
# 335    1
# 336    1
# 337    1
# 338    1
# 339    1
# 340    1
# 341    1
# 342    1
# 343    1
# 344    1
# 345    1
# Name: Relevancia, Length: 346, dtype: int64

# %%
prob_relevante = prob[1]/len(relevs_col)
prob_irrelevante = prob[0]/len(relevs_col)
print(prob_relevante, prob_irrelevante)
# Out:
# 0.7369942196531792 0.2630057803468208
# 1    255
# 0     91
# Name: Relevancia, dtype: int64

# %%
tweets_relevantes = tweets[tweets.Relevancia == 1]
tweets_irrelevantes = tweets[tweets.Relevancia == 0]
# Out:
#                                           Treinamento  Relevancia
# 0   game marvel's spiderman  ps4 caão submarino  r...           0
# 3    promobitoficial promoção ofea  prévenda jogo ...           0
# 6   declare sua independência com o maravilhoso sp...           0
# 7   o pablomiyazawa conversou com a diretora de ae...           0
# 10  americanas game marvel's spiderman  ps4 só r$ ...           0
# 11   ignbrasil o pablomiyazawa conversou com a dir...           0
# 14   ignbrasil o pablomiyazawa conversou com a dir...           0

# %% [markdown]
# ___
# ## Verificando a performance
#
# Agora você deve testar o seu Classificador com a base de Testes.<br /><br />
#
# Você deve extrair as seguintes medidas:
# * Porcentagem de positivos falsos (marcados como relevante mas não são relevantes)
# * Porcentagem de positivos verdadeiros (marcado como relevante e são relevantes)
# * Porcentagem de negativos verdadeiros (marcado como não relevante e não são relevantes)
# * Porcentagem de negativos falsos (marcado como não relevante e são relevantes)
#
# Obrigatório para grupos de 3 alunos:
# * Criar categorias intermediárias de relevância baseado na diferença de probabilidades. Exemplo: muito relevante, relevante, neutro, irrelevante e muito irrelevante.

# %% [markdown]
# ___
# ## Concluindo
#
# Escreva aqui a sua conclusão.<br />
# Faça um comparativo qualitativo sobre as medidas obtidas.<br />
# Explique como são tratadas as mensagens com dupla negação e sarcasmo.<br />
# Proponha um plano de expansão. Por que eles devem continuar financiando o seu projeto?<br />
#
# Opcionalmente:
# * Discorrer por que não posso alimentar minha base de Treinamento automaticamente usando o próprio classificador, aplicado a novos tweets.
# * Propor diferentes cenários de uso para o classificador Naive-Bayes. Cenários sem intersecção com este projeto.
# * Sugerir e explicar melhorias reais no classificador com indicações concretas de como implementar (não é preciso codificar, mas indicar como fazer e material de pesquisa sobre o assunto).
